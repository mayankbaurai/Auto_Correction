# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import re
import textdistance
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
with open('first.txt', 'r') as f:
    file_name_data = f.read()
    file_name_data=file_name_data.lower()
    word1 = re.findall('\w+',file_name_data)

# %%
with open('second.txt', 'r') as f:
    file_name_data = f.read()
    file_name_data=file_name_data.lower()
    words2 = re.findall('\w+',file_name_data)

# %%
with open('third.txt', 'r') as f:
    file_name_data = f.read()
    file_name_data=file_name_data.lower()
    words3 = re.findall('\w+',file_name_data)

# %%
with open('first.txt', 'r') as f:
    file_name_data = f.read()
    file_name_data=file_name_data.lower()
    words4 = re.findall('\w+',file_name_data)

# %%
words = word1+words2 + words3+words4

# %%
## total number of words
len(words)
# Out:
# 337231

# %%
## we are doing tokenization and getting the dict with the words as key and frequency of word as value
t = Tokenizer()
t.fit_on_texts(vocab)

# %%
## Count the word which is being repeated 
t.word_counts.items()
# Out:
# odict_items([('ï', 2), ('the', 18490), ('hunger', 122), ('games', 365), ('1by', 2), ('suzanne', 3), ('collins', 3), ('part', 127), ('i', 13087), ('tributes', 321), ('1', 69), ('when', 1135), ('wake', 55), ('up', 1463), ('other', 374), ('side', 195), ('of', 6550), ('bed', 144), ('is', 2190), ('cold', 82), ('my', 5179), ('fingers', 159), ('stretch', 26), ('out', 1463), ('seeking', 5), ('prims', 42), ('warmth', 23), ('but', 2998), ('finding', 27), ('only', 710), ('rough', 11), ('canvas', 3), ('cover', 54), ('mattress', 2), ('she', 1136), ('must', 390), ('have', 1885), ('had', 606), ('bad', 123), ('dreams', 15), ('and', 7989), ('climbed', 12), ('in', 4992), ('with', 2227), ('our', 722), ('mother', 361), ('course', 164), ('did', 368), ('this', 1249), ('day', 282), ('reaping', 95), ('prop', 6), ('myself', 462), ('on', 2600), ('one', 1335), ('elbow', 13), ('theres', 342), ('enough', 293), ('light', 115), ('bedroom', 10), ('to', 9248), ('see', 715), ('them', 923), ('little', 287), ('sister',
# ...

# %%
## craeting dictionary
dic = {}
for key,value in t.word_counts.items():
    dic[key]=value

# %%
## Calculate the probability of each word in a corpus
total= sum(dic.values())
prob={}
for key,value in dic.items():
    prob[key]=round(value/total,3)

# %%
## Calculating the cosine similarity score of two words with textdistance 
def auto_correct(value):
    value = value.lower()
    if value in vocab:
        return value
    else:
        similarities = [1-(textdistance.Cosine(qval=1).distance(v,str(value))) for v in dic.keys()]
                           
        df = pd.DataFrame.from_dict(prob, orient='index').reset_index()
        df = df.rename(columns={'index':'Word', 0:'Prob'})
        df['Similarity'] = similarities
        output = df.sort_values(['Similarity', 'Prob'], ascending=False).head()
        return output

# %%
auto_correct("drout")
# Out:
#          Word  Prob  Similarity
# 4822     tour   0.0    0.894427
# 1348  outdoor   0.0    0.845154
# 8611  product   0.0    0.845154
# 1604    round   0.0    0.800000
# 3502    doubt   0.0    0.800000
